# %%
import pyvirtualcam
import numpy as np
import cv2
import time
import config

# %%
def __init__(self):
    self.cap = cv2.VideoCapture(config.video_file)
    if (cap.isOpened()== False):  
        print("Error opening video  file")
    self.width = int(self.cap.get(cv2.CAP_PROP_FRAME_WIDTH)//config.webcam_downscale_factor)
    self.height = int(self.cap.get(cv2.CAP_PROP_FRAME_HEIGHT)//config.webcam_downscale_factor)
    self.fps = self.cap.get(cv2.CAP_PROP_FPS)
    self.cam = pyvirtualcam.Camera(width=self.width, height=self.height, fps=self.fps, delay=50)
    self.cap.set(cv2.CAP_PROP_BUFFERSIZE, 4)

# %%
def falseCam(self):
    while(True):
        while(self.cap.isOpened()):
            frame = np.zeros((cam.height, cam.width, 4), np.uint8) # RGBA
            ret, f = cap.read()
            frame[:,:,:3] = cv2.resize(f, (self.width, self.height), interpolation=None)
            if ret:
                #data = np.apply_along_axis(a, -1, np.asarray(frame))
                self.cam.send(frame)
                self.cam.sleep_until_next_frame()
        cap = cv2.VideoCapture(video_name)
# Out:
# (128, 72)
# C:\ProgramData\Anaconda3\lib\site-packages\pyvirtualcam\camera.py:69: UserWarning: current fps (14.7) much lower than camera fps (30.0), consider lowering the camera fps
#   f'current fps ({self._fps_counter.avg_fps:.1f}) much lower '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6c679fb7af70> in <module>
#      16             #data = np.apply_along_axis(a, -1, np.asarray(frame))
#      17             cam.send(frame)
# ---> 18             cam.sleep_until_next_frame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvirtualcam\camera.py in sleep_until_next_frame(self)
#      78         if self._fps_counter.avg_fps > self._fps:
#      79             t_sleep = 1/self._fps - 1/self._fps_counter.avg_fps
# ---> 80             time.sleep(t_sleep)
#      81
#      82
#
# KeyboardInterrupt:

# %%
#'D:\Recordings\FaceRecording.mp4'
if __name__ == "__main__":
    falseCam(0)
    print('tf you running this for?!')
